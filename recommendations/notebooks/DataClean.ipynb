# %%
    
import os
import json

def read_json_files_from_directory(directory_path, filenames):
    json_data = []
    for filename in filenames:
        file_path = os.path.join(directory_path, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
            json_data.append(data)
    return json_data

filenames = [
    'Aussichtspunkt.json',
    'Cafe.json',
    'Höhle.json',
    'Museum.json',
    'Restaurant.json',
    'Schlucht.json',
    'See.json',
    'Wasserfall.json'
]

# Directory containing JSON files
directory_path = '/Users/jianing/Documents/Study/Recsys/Hands-On-Recommender-System/recommendations/rec_data'

# Read the JSON files and assign them to variables
json_data_list = read_json_files_from_directory(directory_path, filenames)

# Assign each JSON data to a separate variable
aussichtspunkt, cafe, hohle, museum, restaurant, schlucht, see, wasserfall = json_data_list

# %%
import time
import requests
all_category = [aussichtspunkt, cafe, hohle, museum, restaurant, schlucht, see, wasserfall]


def get_city_from_coordinates(latitude, longitude):
    url = f"https://geocode.maps.co/reverse?lat={latitude}&lon={longitude}&api_key=6689cf0c73825558027087gwdd4e547"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        json_response = response.json()
        # print(json_response)
        if 'address' in json_response and 'city' in json_response['address']:
            return json_response['address']['city']
        elif 'address' in json_response and 'county' in json_response['address']:
            return json_response['address']['county']  # 使用县作为备选
        else:
            return "City not found"
    except requests.RequestException as e:
        return f"Request failed: {e}"

results = []

def analyze_data(data, output_filename):
    city_set = set()
    if not os.path.exists(output_filename):
        with open(output_filename, 'w', encoding='utf-8') as json_file:
            json.dump([], json_file)
            
    for item in data:
        longitude, latitude = item['geometry'].split(',')
        time.sleep(1.1)
        city = get_city_from_coordinates(latitude, longitude)
        city_set.add(city)
        item['city'] = city
        with open(output_filename, 'r+', encoding='utf-8') as json_file:
            file_data = json.load(json_file)
            file_data.append(item)
            json_file.seek(0)
            json.dump(file_data, json_file, ensure_ascii=False, indent=4)

    return data

# for item in all_category:
# dataaussichtspunkt = analyze_data(aussichtspunkt)
# datacafe = analyze_data(cafe)
# print('1')
# datahohle = analyze_data(hohle, 'city_result_hohle.json')
# print('1')
# datamuseum = analyze_data(museum, 'city_result_museum.json')
print('1')
datarestaurant = analyze_data(restaurant, 'city_result_restaurant.json')
print('1')
# dataschlucht = analyze_data(schlucht, 'city_result_see.json')
# print('1')
# datasee = analyze_data(see, 'city_result_wasserfallt.json')
# print('1')
# datawasserfall = analyze_data(wasserfall, 'city_result_wasserfallt.json')
# print(data)

# with open('city_result_aussichtspunkt.json', 'w', encoding='utf-8') as json_file:
#     json.dump(dataaussichtspunkt, json_file, ensure_ascii=False, indent=4)

# with open('city_result_cafet.json', 'w', encoding='utf-8') as json_file:
#     json.dump(datacafe, json_file, ensure_ascii=False, indent=4)

# with open('city_result_hohle.json', 'w', encoding='utf-8') as json_file:
#     json.dump(datahohle, json_file, ensure_ascii=False, indent=4)

# with open('city_result_museum.json', 'w', encoding='utf-8') as json_file:
#     json.dump(datamuseum, json_file, ensure_ascii=False, indent=4)

# with open('city_result_restaurant.json', 'w', encoding='utf-8') as json_file:
#     json.dump(datarestaurant, json_file, ensure_ascii=False, indent=4)

# with open('city_result_see.json', 'w', encoding='utf-8') as json_file:
#     json.dump(datasee, json_file, ensure_ascii=False, indent=4)

# with open('city_result_wasserfallt.json', 'w', encoding='utf-8') as json_file:
#     json.dump(datawasserfall, json_file, ensure_ascii=False, indent=4)

# with open('city_result_schlucht.json', 'w', encoding='utf-8') as json_file:
#     json.dump(dataschlucht, json_file, ensure_ascii=False, indent=4)

print("saved")
# Out:
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 53
#      45 # for item in all_category:
#      46 # dataaussichtspunkt = analyze_data(aussichtspunkt)
#      47 # datacafe = analyze_data(cafe)
#    (...)
#      50 # print('1')
#      51 # datamuseum = analyze_data(museum, 'city_result_museum.json')
#      52 print('1')
# ---> 53 datarestaurant = analyze_data(restaurant, 'city_result_restaurant.json')
#      54 print('1')
#      55 # dataschlucht = analyze_data(schlucht, 'city_result_see.json')
#      56 # print('1')
#      57 # datasee = analyze_data(see, 'city_result_wasserfallt.json')
#    (...)
#      83 # with open('city_result_schlucht.json', 'w', encoding='utf-8') as json_file:
#      84 #     json.dump(dataschlucht, json_file, ensure_ascii=False, indent=4)
#
# Cell In[13], line 41, in analyze_data(data, output_filename)
# ...

# %%
import time
import requests
all_category = [aussichtspunkt, cafe, hohle, museum, restaurant, schlucht, see, wasserfall]


def get_city_from_coordinates(latitude, longitude):
    url = f"https://geocode.maps.co/reverse?lat={latitude}&lon={longitude}&api_key=6689cf0c73825558027087gwdd4e547"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        json_response = response.json()
        # print(json_response)
        if 'address' in json_response and 'city' in json_response['address']:
            return json_response['address']['city']
        elif 'address' in json_response and 'county' in json_response['address']:
            return json_response['address']['county']  # 使用县作为备选
        else:
            return "City not found"
    except requests.RequestException as e:
        return f"Request failed: {e}"

results = []

def analyze_data(data, output_filename):
    city_set = set()
    if not os.path.exists(output_filename):
        with open(output_filename, 'w', encoding='utf-8') as json_file:
            json.dump([], json_file)
            
    for item in data:
        longitude, latitude = item['geometry'].split(',')
        time.sleep(1.1)
        city = get_city_from_coordinates(latitude, longitude)
        city_set.add(city)
        item['city'] = city
        with open(output_filename, 'r+', encoding='utf-8') as json_file:
            file_data = json.load(json_file)
            file_data.append(item)
            json_file.seek(0)
            json.dump(file_data, json_file, ensure_ascii=False, indent=4)

    return data


print('schlucht')
dataschlucht = analyze_data(schlucht, 'city_result_see.json')
print('see')
datasee = analyze_data(see, 'city_result_wasserfallt.json')
print('wasserfall')
# datawasserfall = analyze_data(wasserfall, 'city_result_wasserfallt.json')


print("saved")
# Out:
# schlucht
# see
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 49
#      47 dataschlucht = analyze_data(schlucht, 'city_result_see.json')
#      48 print('see')
# ---> 49 datasee = analyze_data(see, 'city_result_wasserfallt.json')
#      50 print('wasserfall')
#      51 # datawasserfall = analyze_data(wasserfall, 'city_result_wasserfallt.json')
#
# Cell In[16], line 38, in analyze_data(data, output_filename)
#      36 item['city'] = city
#      37 with open(output_filename, 'r+', encoding='utf-8') as json_file:
# ---> 38     file_data = json.load(json_file)
#      39     file_data.append(item)
#      40     json_file.seek(0)
#
# File ~/miniconda3/envs/recsystest/lib/python3.12/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
import json

# 假设您的JSON文件名为data.json
filename = '/Users/jianing/Documents/Study/Recsys/Hands-On-Recommender-System/recommendations/travel_data.json'

# 读取JSON文件内容
with open(filename, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 计算项目数量
item_count = len(data)
print(f"JSON文件中有 {item_count} 个项目。")
# Out:
# JSON文件中有 187 个项目。

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from nltk.corpus import stopwords
import string
import json
from deep_translator import GoogleTranslator
nltk.download('stopwords')

with open('./gpt_data/Amsterdam_travel_data.json') as f:
    activities_data = json.load(f)
    
# 从JSON文件加载活动数据
with open('./add_city_data/city_result_museum.json') as f:
    museum_data = json.load(f)

def preprocess_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    words = text.split()
    words = [word for word in words if word not in stopwords.words('english')]
    return ' '.join(words)

# 创建活动DataFrame
# activities = pd.DataFrame(activities_data)
museum_data = pd.DataFrame(museum_data)

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

museum_data_df = museum_data[['title', 'homepage', 'address', 'city', 'businessHours', 'shortText', 'geometry', 'ranking', 'countryCode']]
vectorizer = TfidfVectorizer()

# 显示新的 DataFrame
# print(museum_data_df)
# def recommend_museum_data(user_hobbies, museum_data_df):
# hobby_description = preprocess_text(user_hobbies)
for idx, museum_data in museum_data_df.iterrows():
    recommended = []
    museum_data['combined_text'] = museum_data['title'] + " " + museum_data['shortText']
    museum_data['combined_text'] = GoogleTranslator(source='auto', target='en').translate(str(museum_data['combined_text']))
    
    museum_data['processed_description'] = preprocess_text(museum_data['combined_text'])
    museum_processed = museum_data['processed_description']
    museum_processed.replace('<p>', '').replace('</p>', '')
    print(museum_processed)
    #     similarity = cosine_similarity(vectorizer.transform(hobby_description), vectorizer.transform([museum_processed]))[0][0]
    #     if similarity > 0.1:
    #         recommended.append((similarity, museum_data))
    #     recommended.sort(reverse=True, key=lambda x: x[0])
    #     top_activities = recommended[:10]  
        
    # return [activity for _, activity in top_activities]

# 取相似度最高的前5个活动
# museum_data_df['processed_combined_text'] = museum_data_df['combined_text'].apply(preprocess_text)

# # description = preprocess_text(museum_data_df['combined_text'])
# # # print(museum_data_df['combined_text'].head())
# print(museum_data_df['processed_combined_text'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jianing/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# aeronauticum german airship naval aviation museum nordholz aeronauticum museum dedicated history sea naval aviation
# house silk culture house silk culture represents piece krefelds living textile history impressively attention detail
# villa merländer villa silk manufacturer richard merländer used documentation center nazi era facility affiliated city archives city krefeld richard merländer victim national socialist regime jewish faith since 1991 villa merländer ev looking memory processing krefelds nazi history
# dujardin distillery pthe historic wine distillery rhine combines living tradition contemporary lifestylep
# themed tour «anna maria wocher thun panorama» learn anna maria wocher husband created first panorama switzerland
# themed tour «thun panorama» visits thun oldest surviving panorama world
# ...

# %% [markdown]
# df['combined_text'] = df['title'] + " " + df['shortText']
#
# # Apply TF-IDF vectorization
# tfidf_vectorizer = TfidfVectorizer(stop_words='english')
# tfidf_matrix = tfidf_vectorizer.fit_transform(df['combined_text'])
#
# # Compute cosine similarity matrix
# cosine_sim_matrix = cosine_similarity(tfidf_matrix)
#
# # Find the attraction which is similar with "Kuminda Farm"
# similar_attractions = get_similar_attractions('Kuminda Farm', df, cosine_sim_matrix)
# print("Recommended Attractions:" )
# print(similar_attractions)

# %%
import pandas as pd
from ftfy import fix_text

# Example dictionary containing your data
data = [{
    "title": "Mus\u221a\u00a9e du Revermont",
    "homepage": "https://patrimoines.ain.fr/agenda/7",
    "address": "{'street': '40 rue Principale', 'zipcode': '01370', 'town': 'Val-Revermont', 'countryname': 'Frankreich'}",
    "city": "Request failed: 429 Client Error: Too Many Requests for url: https://geocode.maps.co/reverse?lat=46.300379&lon=5.388898&api_key=6689cf0c73825558027087gwdd4e547",
    "businessHours": "Vom 15/03 bis 30/06/2024 <br/>Öffnungszeiten jeden Mittwoch, Donnerstag, Freitag, Samstag und Sonntag von 10 Uhr bis 12.30 Uhr und von 13.30 Uhr bis 18 Uhr.<br/>Montag und Dienstag geschlossen.<br/>Ausnahmsweise geschlossen am 1. Mai.<br/><br/>Vom 01/07 bis 31/08/2024 von 10 Uhr bis 18 Uhr.<br/>Montag und Dienstag geschlossen.<br/><br/>Vom 01/09 bis 15/11/2024 <br/>Öffnungszeiten jeden Mittwoch, Donnerstag, Freitag, Samstag und Sonntag von 10 Uhr bis 12.30 Uhr und von 13.30 Uhr bis 18 Uhr.<br/>Montag und Dienstag geschlossen.",
    "shortText": "Au pied des premiers contreforts du Jura, au coeur du village de Cuisiat, le musée est installé dans l'ancienne mairie école et se caractérise par un jardin avec un potager-verger conservatoire où plus de 650 variétés sont conservées et/ou cultivées.",
    "geometry": "5.388898,46.300379",
    "ranking": 93,
    "countryCode": "FR",
    "Unnamed: 9": None,
    "Unnamed: 10": None,
    "Unnamed: 11": None,
    "geom_lon": 5.388898,
    "geom_lat": 46.300379,
    "distance": 7.862251366,
    "combined_text": "Musée du Revermont Au pied des premiers contreforts du Jura, au coeur du village de Cuisiat, le musée est installé dans l'ancienne mairie école et se caractérise par un jardin avec un potager-verger conservatoire où plus de 650 variétés sont conservées et/ou cultivées.",
    "processed_description": "Revermont Museum At the foot of the first foothills of the Jura, in the heart of the village of Cuisiat, the museum is located in the former town hall and school and is characterized by a garden with a vegetable garden -conservatory orchard where more than 650 varieties are preserved and/or cultivated."
}]

# Create a DataFrame
def clean_result(data):
    df = pd.DataFrame(data)
    # Drop unwanted columns
    columns_to_drop = ['city', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'geom_lon', 'geom_lat', 'combined_text']
    df.drop(columns=columns_to_drop, inplace=True)
    # Fix encoding issues
    string_columns = df.select_dtypes(include=['object']).columns
    # Apply fix_text only to string columns
    df[string_columns] = df[string_columns].applymap(fix_text)
    json_result = df.to_json(orient='records', force_ascii=False, indent=4)
    return json_result

clean_result(data)
# Out:
# /var/folders/md/00znqx716_b042ykzg2k80g80000gn/T/ipykernel_60888/1832778902.py:34: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[string_columns] = df[string_columns].applymap(fix_text)
# ...
