# %%
import json

# 打开文件并加载数据
with open('/Users/jianing/Documents/Study/Recsys/Hands-On-Recommender-System/recommendations/allCountries.json', 'r') as file:
    data = json.load(file)

with open('/Users/jianing/Documents/Study/Recsys/Hands-On-Recommender-System/recommendations/France.json', 'r') as file:
    data_france = json.load(file)
    
with open('/Users/jianing/Documents/Study/Recsys/Hands-On-Recommender-System/recommendations/rec_data/Museum.json', 'r') as file:
    data_museum = json.load(file)
    
import os
import json

def read_json_files_from_directory(directory_path, filenames):
    json_data = []
    for filename in filenames:
        file_path = os.path.join(directory_path, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
            json_data.append(data)
    return json_data

filenames = [
    'Aussichtspunkt.json',
    'Cafe.json',
    'Höhle.json',
    'Museum.json',
    'Restaurant.json',
    'Schlucht.json',
    'See.json',
    'Wasserfall.json'
]

# Directory containing JSON files
directory_path = '/Users/jianing/Documents/Study/Recsys/Hands-On-Recommender-System/recommendations/rec_data'

# Read the JSON files and assign them to variables
json_data_list = read_json_files_from_directory(directory_path, filenames)

# Assign each JSON data to a separate variable
aussichtspunkt, cafe, hohle, museum, restaurant, schlucht, see, wasserfall = json_data_list

# %%
from collections import defaultdict

country_count = {}
all_category = [aussichtspunkt, cafe, hohle, museum, restaurant, schlucht, see, wasserfall]

print('museum')
for item in museum:
    country = item['address']['countryname']
    if country in country_count:
        country_count[country] += 1
    else:
        country_count[country] = 1

print(country_count)

print('aussichtspunkt')
for item in aussichtspunkt:
    country = item['address']['countryname']
    if country in country_count:
        country_count[country] += 1
    else:
        country_count[country] = 1

print(country_count)

print('cafe')
for item in cafe:
    if 'address' in item and 'countryname' in item['address']:
        country = item['address']['countryname']
        if country in country_count:
            country_count[country] += 1
        else:
            country_count[country] = 1

print(country_count)

print('hohle')
for item in hohle:
    country = item['address']['countryname']
    if country in country_count:
        country_count[country] += 1
    else:
        country_count[country] = 1

print(country_count)

print('restaurant')
for item in restaurant:
    country = item['address']['countryname']
    if country in country_count:
        country_count[country] += 1
    else:
        country_count[country] = 1

print(country_count)

print('schlucht')
for item in schlucht:
    country = item['address']['countryname']
    if country in country_count:
        country_count[country] += 1
    else:
        country_count[country] = 1

print(country_count)

print('see')
for item in see:
    country = item['address']['countryname']
    if country in country_count:
        country_count[country] += 1
    else:
        country_count[country] = 1

print(country_count)

print('wasserfall')
for item in wasserfall:
    country = item['address']['countryname']
    if country in country_count:
        country_count[country] += 1
    else:
        country_count[country] = 1

print(country_count)

# %%
for index, item in enumerate(cafe):
    print(f"Item {index + 1}:")
    for key, value in item.items():
        print(f"Key: {key} - Value: {value}")
    print("\n-----------------\n")

# %%
# 遍历每个起点信息
for item in data:
    title = item['category']
    print(f"category: {title}")

# %%
country_count = {}
for item in data:
    country = item['address']['countryname']
    if country in country_count:
        country_count[country] += 1
    else:
        country_count[country] = 1

print(country_count)

# %%
country_count = {}
for item in data:
    country = item['address']['countryname']
    if country in country_count:
        country_count[country] += 1
    else:
        country_count[country] = 1

print(country_count)

# %%
country_count = {}
for item in data:
    country = item['category']['name']
    if country in country_count:
        country_count[country] += 1
    else:
        country_count[country] = 1

print(country_count)

# %%
from collections import defaultdict

# 创建一个默认字典来存储每个国家的category name的计数
category_counts = defaultdict(lambda: defaultdict(int))

# 填充字典
for item in data:
    country = item['address']['countryname']
    category_name = item['category']['name']
    category_counts[country][category_name] += 1

# 输出每个国家的category name计数
for country, categories in category_counts.items():
    print(f"Country: {country}")
    for category, count in categories.items():
        print(f"  Category Name: {category} - Count: {count}")
    print()

# %%
total_items = len(country_count)
print(total_items)

# %%
import requests

def get_city_from_coordinates(latitude, longitude):
    # 构建API请求URL
    # url = f"https://geocode.maps.co/reverse?lat={latitude}&lon={longitude}"
    url = f"https://geocode.maps.co/reverse?lat={latitude}&lon={longitude}&api_key=6689cf0c73825558027087gwdd4e547"
    try:
        # 发送GET请求
        response = requests.get(url)
        # 确保请求成功
        response.raise_for_status()
        
        # 解析JSON响应
        
        json_response = response.json()
        
        # 寻找城市名称
        # 注：实际结构可能需要调整，具体取决于API响应
        # city = json_response['address']['city']
        return json_response
    
    except requests.RequestException as e:
        print(f"Error: {e}")
        return None
# 116.3786,39.902051
# 示例坐标，需要替换为你需要查询的坐标
# 8.639217,53.774531
latitude = 53.774531
longitude = 8.639217
city = get_city_from_coordinates(latitude, longitude)

print(f"The city for the coordinates ({latitude}, {longitude}) is: {city}")

# %%
import time
import requests
all_category = [aussichtspunkt, cafe, hohle, museum, restaurant, schlucht, see, wasserfall]


def get_city_from_coordinates(latitude, longitude):
    url = f"https://geocode.maps.co/reverse?lat={latitude}&lon={longitude}&api_key=6689cf0c73825558027087gwdd4e547"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        json_response = response.json()
        # print(json_response)
        if 'address' in json_response and 'city' in json_response['address']:
            return json_response['address']['city']
        elif 'address' in json_response and 'county' in json_response['address']:
            return json_response['address']['county']  # 使用县作为备选
        else:
            return "City not found"
    except requests.RequestException as e:
        return f"Request failed: {e}"

results = []

def analyze_data(data):
    city_set = set()
    for item in data:
        longitude, latitude = item['geometry'].split(',')
        time.sleep(1.1)
        city = get_city_from_coordinates(latitude, longitude)
        city_set.add(city)
        item['city'] = city
        # print(item)
    return data

# for item in all_category:
data = analyze_data(aussichtspunkt)
# print(data)

with open('city_result_aussichtspunkt.json', 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False, indent=4)

print("字典已成功保存为JSON文件")
# Out:
# 字典已成功保存为JSON文件

# %%
import pandas as pd
import json

# 加载JSON数据
with open('/Users/jianing/Documents/Study/Recsys/Hands-On-Recommender-System/recommendations/final_data/France.json', 'r') as file:
    city_result_aussichtspunkt = json.load(file)

# 提取所需字段
aussichtspunkt = [
    {
        "title": item.get("title"),
        "homepage": item.get("homepage"),
        "address": item.get("address"),
        "city": item.get("city"),
        "businessHours": item.get("businessHours"),
        "shortText": item.get("shortText"),
        "geometry": item.get("geometry"),
        "ranking": item.get("ranking"),
        "countryCode": item.get("countryCode"),
        "category": item.get("category", {}).get("datatype", [None])[0]  # 提取第一个元素，如果不存在则为None
    }
    for item in city_result_aussichtspunkt
]

# 转换为DataFrame
df_aussichtspunkt = pd.DataFrame(aussichtspunkt)

# 保存为CSV文件
df_aussichtspunkt.to_csv("./df_france2.csv", index=False)

# %%
with open('/Users/jianing/Documents/Study/Recsys/Hands-On-Recommender-System/recommendations/df_hohle.csv', 'r') as file:
    data = json.load(file)

# pd.set_option('display.max_rows', 20)  # 显示所有行
# pd.set_option('display.max_columns', None)  # 显示所有列
city_counts = pd.Series([item.get("city") for item in data]).value_counts().reset_index()
city_counts.columns = ["city", "count"]
print(city_counts)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[28], line 2
#       1 with open('/Users/jianing/Documents/Study/Recsys/Hands-On-Recommender-System/recommendations/df_hohle.csv', 'r') as file:
# ----> 2     data = json.load(file)
#       4 # pd.set_option('display.max_rows', 20)  # 显示所有行
#       5 # pd.set_option('display.max_columns', None)  # 显示所有列
#       6 city_counts = pd.Series([item.get("city") for item in data]).value_counts().reset_index()
#
# File ~/miniconda3/envs/recsystest/lib/python3.12/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
# ...

# %%
import time
import requests
    
import os
import json

def read_json_files_from_directory(directory_path, filenames):
    json_data = []
    for filename in filenames:
        file_path = os.path.join(directory_path, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
            json_data.append(data)
    return json_data

filenames = [
    'Aussichtspunkt.json',
    'Cafe.json',
    'Höhle.json',
    'Museum.json',
    'Restaurant.json',
    'Schlucht.json',
    'See.json',
    'Wasserfall.json'
]

# Directory containing JSON files
directory_path = '/Users/jianing/Documents/Study/Recsys/Hands-On-Recommender-System/recommendations/rec_data'

# Read the JSON files and assign them to variables
json_data_list = read_json_files_from_directory(directory_path, filenames)

# Assign each JSON data to a separate variable
aussichtspunkt, cafe, hohle, museum, restaurant, schlucht, see, wasserfall = json_data_list


def get_city_from_coordinates(latitude, longitude):
    url = f"https://geocode.maps.co/reverse?lat={latitude}&lon={longitude}&api_key=6689cf0c73825558027087gwdd4e547"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        json_response = response.json()
        # print(json_response)
        if 'address' in json_response and 'city' in json_response['address']:
            return json_response['address']['city']
        elif 'address' in json_response and 'county' in json_response['address']:
            return json_response['address']['county']  # 使用县作为备选
        else:
            return "City not found"
    except requests.RequestException as e:
        return f"Request failed: {e}"


def analyze_data(data, output_filename):
    city_set = set()
    if not os.path.exists(output_filename):
        with open(output_filename, 'w', encoding='utf-8') as json_file:
            json.dump([], json_file)
            
    for item in data:
        longitude, latitude = item['geometry'].split(',')
        time.sleep(1.1)
        city = get_city_from_coordinates(latitude, longitude)
        city_set.add(city)
        item['city'] = city
        with open(output_filename, 'r+', encoding='utf-8') as json_file:
            file_data = json.load(json_file)
            file_data.append(item)
            json_file.seek(0)
            json.dump(file_data, json_file, ensure_ascii=False, indent=4)

    return data


print('see')
dataschlucht = analyze_data(see, 'city_result_see.json')
print('schlucht')
datasee = analyze_data(schlucht, 'city_result_schlucht.json')
print('wasserfall')
datawasserfall = analyze_data(wasserfall, 'city_result_wasserfallt.json')


print("saved")
# Out:
# schlucht
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 47
#      43     return data
#      46 print('schlucht')
# ---> 47 dataschlucht = analyze_data(schlucht, 'city_result_see.json')
#      48 print('see')
#      49 datasee = analyze_data(see, 'city_result_wasserfallt.json')
#
# Cell In[21], line 33, in analyze_data(data, output_filename)
#      31 for item in data:
#      32     longitude, latitude = item['geometry'].split(',')
# ---> 33     time.sleep(1.1)
#      34     city = get_city_from_coordinates(latitude, longitude)
#      35     city_set.add(city)
#
# KeyboardInterrupt:

# %%
import time

def get_city_from_coordinates(latitude, longitude):
    url = f"https://geocode.maps.co/reverse?lat={latitude}&lon={longitude}&api_key=6689cf0c73825558027087gwdd4e547"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        json_response = response.json()
        
        if 'address' in json_response and 'city' in json_response['address']:
            return json_response['address']['city']
        if 'address' in json_response and 'municipality' in json_response['address']:
            return json_response['address']['municipality']
        elif 'address' in json_response and 'county' in json_response['address']:
            return json_response['address']['county']  # 使用县作为备选
        else:
            return "City not found"
        # return json_response
    except requests.RequestException as e:
        return f"Request failed: {e}"

def analyze_data(data):
    city_category_counts = {}
    for item in data:
        longitude, latitude = item['geometry'].split(',')
        time.sleep(1.1)
        city = get_city_from_coordinates(latitude, longitude)
        
        if city not in city_category_counts:
            city_category_counts[city] = {'total_activity_count': 0, 'each_activity_count': {}, 'unique_activity': set()}

        datatypes = item['category'].get('datatype', [item['category']['name']])
        
        # datatypes = item['category']['datatype']
        # category_name = item['category']['name']
        for datatype in datatypes:
            if datatype not in city_category_counts[city]['unique_activity']:
                city_category_counts[city]['each_activity_count'][datatype] = 0
            city_category_counts[city]['each_activity_count'][datatype] += 1
            city_category_counts[city]['unique_activity'].add(datatype)
            city_category_counts[city]['total_activity_count'] += 1
        print(city_category_counts)
        
    return city_category_counts

results_france = analyze_data(data_france)
print(results_france)

# results_fr = []

# # 遍历数据集，提取和查询每个坐标的城市
# for item in data_france:
#     longitude, latitude = item['geometry'].split(',')
#     city = get_city_from_coordinates(latitude, longitude)
#     print(f"Coordinates: ({latitude}, {longitude}) - City: {city}")
    
#     # result_dict = {
#     #     "Coordinates": f"({latitude}, {longitude})",
#     #     "City": city
#     # }
#     result_dict = {
#         "Coordinates": f"({latitude}, {longitude})",
#         "City": city,
#         "Activity": category_name,
#         "Activity Count": 
#     }
#     results_fr.append(result_dict)
    
#     time.sleep(1.1)

# %%
# Create a set of unique city names from the results_fr list
unique_cities = set(item['City'] for item in results_fr)

# Convert the set back to list to display it properly
list(unique_cities)

# %%
from collections import defaultdict

# 创建一个默认字典来存储每个国家的category name的计数
category_counts = defaultdict(lambda: defaultdict(int))

# 填充字典
for item in data:
    country = item['address']['countryname']
    category_name = item['category']['name']
    category_counts[country][category_name] += 1

# 输出每个国家的category name计数
for country, categories in category_counts.items():
    print(f"Country: {country}")
    for category, count in categories.items():
        print(f"  Category Name: {category} - Count: {count}")
    print()

# %%
import sys
import os
sys.path.append(os.path.abspath('../'))
from CityRecommender import CityRecommender
from UserMatcher import UserMatcher
from ActivityRecommender import ActivityRecommender

host = "recsys.postgres.database.azure.com"
port = 5432
db_name = "postgres"
username = "recsys_user"
password = "team5!123"
# user_data = {
#     "userId": 1,
#     "startDate": "2024-07-22 22:00:00",
#     "endDate": "2024-07-29 22:00:00",
#     "reliabilityRating": 5,
#     "flexibilityRating": 4,
#     "organizationRating": 3,
#     "sociabilityRating": 2,
#     "daynightPreference": "NIGHTOWL",
#     "travelPacePreference": "MEDIUM",
    # "sociabilityRating": 2,
    # "accomondations": [
    #         "hotel",
    #         "vacationApartment"
    #     ],
#     "hobbies": ["adventure", "culture", "natureAndWildlife", "beachAndResort"],
#     "travelStyles": ["adventure", "culture"],
#     "destination1": "Nairobi",
#     "destination2": "Oslo",
#     "destination3": "Florence"
# }


user_data = {
    "userId": 10,
    "reliabilityRating": 5,
    "flexibilityRating": 4,
    "organizationRating": 3,
    "sharedInterestsRating": 1,
    "daynightPreference": "NIGHTOWL",
    "travelPacePreference": "MEDIUM",
    "foodPreference": 5,
    "groupSizePreference": "MEDIUM",
    "sociabilityRating": 2,
    "accomondations": [
            "hotel",
            "vacationApartment"
        ],
    "budget": 220,
    "hobbies": {4,5},
    "travelStyles": [
            "adventure",
            "culture",
            # "natureAndWildlife",
            # "beachAndResort"
        ],
    "destinationRating1": 4,
    "destinationRating2": 5,
    "destinationRating3": 2,
    "destination1": "Madrid",
    "destination2": "Rome",
    "destination3": "Amsterdam"
}

matcher = UserMatcher(user_data, host, port, db_name, username, password)
# matcher.get_all_user_data()
matcher.find_best_matches(1)
# Out:
# Successfully connected to the PostgreSQL database
# {'MatchQuestionaireId': 7, 'startDate': '2024-07-22 22:00:00', 'endDate': '2024-07-29 22:00:00', 'reliabilityRating': 5, 'flexibilityRating': 4, 'organizationRating': 3, 'sharedInterestsRating': 1, 'daynightPreference': 'NIGHTOWL', 'travelPacePreference': 'MEDIUM', 'foodPreference': 5, 'groupSizePreference': 'MEDIUM', 'createdAt': '2024-07-04 21:44:23.266000', 'updatedAt': '2024-07-04 21:54:38.465000', 'userId': 1, 'sociabilityRating': 2, 'accomondations': ['hotel', 'vacationApartment'], 'budget': 220, 'hobbies': [4, 5], 'travelStyles': ['adventure', 'culture', 'natureAndWildlife', 'beachAndResort'], 'destinationRating1': 4, 'destinationRating2': 5, 'destinationRating3': 2, 'destination1': 'Nairobi', 'destination2': 'Oslo', 'destination3': 'Florence'}
# <class 'dict'>
# 1
# 11.0
# ...
