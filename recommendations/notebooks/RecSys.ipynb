# %%
# Importing necessary libraries
import json
import glob
import re
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go


from sklearn.preprocessing import normalize, MinMaxScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
# from sklearn.metrics import r2_score
# from sklearn.cluster import KMeans


from surprise import Dataset, Reader, KNNBasic, SVD, NMF, KNNWithMeans, SVDpp
from surprise.model_selection import train_test_split
from surprise import accuracy as sup_accuracy
from surprise.prediction_algorithms.matrix_factorization import NMF
from surprise.prediction_algorithms.matrix_factorization import SVD
from surprise.prediction_algorithms.matrix_factorization import SVDpp
from surprise.model_selection import cross_validate
from surprise import accuracy

import warnings

from DataProcessor import DataProcessor, PerformanceMetrics, recommend_amenities, recommend_attraction, recommend_country,  get_similar_attractions, RecommendationEngine

# %% [markdown]
# ### Collaborative Filtering:

# %% [markdown]
# #### 1. Read Data

# %%
#read travel info data
info = pd.read_csv('../data/test_travel_data.csv')
info.columns
# Out:
# Index(['id', 'type', 'subcategories', 'name', 'description', 'rating',
#        'latitude', 'longitude', 'numberOfReviews', 'amenities', 'LowerPrice',
#        'UpperPrice', 'Rank', 'Total', 'Location', 'RankingType', 'country',
#        'city', 'regional_rating'],
#       dtype='object')

# %%
#read review data
reviews = pd.read_csv('../data/test_reviews_data.csv', index_col=0)
reviews.reset_index(inplace=True)
reviews.columns
# Out:
# Index(['userId', 'placeid', 'rating', 'lang', 'text'], dtype='object')

# %%
reviews.head(5)
# Out:
#                              userId  placeid  rating lang  \
# 0  A87669AAD9DA05FFBD46F1334B329FFD  2189822       5   en
# 1  9FFED7DDC68883BBB8F4024333970E9A  2189822       5   en
# 2  B5E56A483B579518DDD82A3DA0E94487  2189822       4   en
# 3  882D0A6C7152105BB0D83C84F3CB160D  2189822       5   en
# 4  203EBC7F3F51AAAA39A87D2E58842C76  2189822       5   en
#
#                                                 text
# 0  Gee is a passionate tour guide. The  animals a...
# 1  Lots to see. Easy to get to from the Safari Lo...
# 2  a kind of a zoo for injured and saved animals ...
# 3  They do great rehabilitating injured animals. ...
# 4  We took the guided tour from Isaac, who was gr...

# %%
matched_reviews_info = info[info['id'].isin(reviews['placeid'])]
# print(matched_reviews_info)
merged_reviews_info = pd.merge(matched_reviews_info, reviews, left_on='id', right_on='placeid', how='inner')
# merged_reviews_info.columns
print(merged_reviews_info)
merged_reviews_info.to_csv('merged_reviews_info.csv', index=False)
# Out:
#              id        type       subcategories           name  \
# 0       7945044  ATTRACTION  Sights & Landmarks   Kuminda Farm
# 1       7945044  ATTRACTION  Sights & Landmarks   Kuminda Farm
# 2       7945044  ATTRACTION  Sights & Landmarks   Kuminda Farm
# 3       7945044  ATTRACTION  Sights & Landmarks   Kuminda Farm
# 4       7945044  ATTRACTION  Sights & Landmarks   Kuminda Farm
# ...         ...         ...                 ...            ...
# 31074  14903233  ATTRACTION      Nature & Parks  Mutanda Falls
# 31075  14903233  ATTRACTION      Nature & Parks  Mutanda Falls
# 31076  14903233  ATTRACTION      Nature & Parks  Mutanda Falls
# 31077  14903233  ATTRACTION      Nature & Parks  Mutanda Falls
# 31078  14903233  ATTRACTION      Nature & Parks  Mutanda Falls
#
#                                              description  rating_x  latitude  \
# 0      It's a small farm and we are into Argo tourism...       5.0    -20.98
# 1      It's a small farm and we are into Argo tourism...       5.0    -20.98
# 2      It's a small farm and we are into Argo tourism...       5.0    -20.98
# 3      It's a small farm and we are into Argo tourism...       5.0    -20.98
# 4      It's a small farm and we are into Argo tourism...       5.0    -20.98
# ...                                                  ...       ...       ...
# 31074  It is samall water fall, on Mutanda River, Loc...       4.0    -12.39
# 31075  It is samall water fall, on Mutanda River, Loc...       4.0    -12.39
# 31076  It is samall water fall, on Mutanda River, Loc...       4.0    -12.39
# 31077  It is samall water fall, on Mutanda River, Loc...       4.0    -12.39
# 31078  It is samall water fall, on Mutanda River, Loc...       4.0    -12.39
#
#        longitude  numberOfReviews      amenities  ...     Location  \
# 0          27.25               22  bathroom only  ...  Francistown
# 1          27.25               22  bathroom only  ...  Francistown
# 2          27.25               22  bathroom only  ...  Francistown
# 3          27.25               22  bathroom only  ...  Francistown
# 4          27.25               22  bathroom only  ...  Francistown
# ...          ...              ...            ...  ...          ...
# 31074      26.24                7  bathroom only  ...      Solwezi
# 31075      26.24                7  bathroom only  ...      Solwezi
# 31076      26.24                7  bathroom only  ...      Solwezi
# 31077      26.24                7  bathroom only  ...      Solwezi
# 31078      26.24                7  bathroom only  ...      Solwezi
#
#         RankingType   country         city regional_rating  \
# 0      things to do  Botswana  Francistown             3.0
# 1      things to do  Botswana  Francistown             3.0
# 2      things to do  Botswana  Francistown             3.0
# 3      things to do  Botswana  Francistown             3.0
# 4      things to do  Botswana  Francistown             3.0
# ...             ...       ...          ...             ...
# 31074  things to do    Zambia      Solwezi             2.0
# 31075  things to do    Zambia      Solwezi             2.0
# 31076  things to do    Zambia      Solwezi             2.0
# 31077  things to do    Zambia      Solwezi             2.0
# 31078  things to do    Zambia      Solwezi             2.0
#
#                                  userId   placeid rating_y  lang  \
# 0      9CEA26E89517E8044ACDF8AEEA0B7D47   7945044        5    en
# 1      2A5836BDB7EDEEB43BF1F6AE6A9C28F7   7945044        5    en
# 2      6B6FF15762B659D0EB3EF2619687FDE4   7945044        5    en
# 3      EEDE651FE073F7B53815424411D8A07D   7945044        5    en
# 4      7FC73CFBD2C86EACA8EB4E0482F00AD0   7945044        5    en
# ...                                 ...       ...      ...   ...
# 31074  A38CEED23744265FCA6202C3869DFE93  14903233        4    en
# 31075  5A4A867DDBA245589A93F86E6A3DB615  14903233        4    en
# 31076  248BA71CBBF32B06A444F1074C5B32E2  14903233        4    en
# 31077  BE4E3055F78F7BCC56D535EAD892F409  14903233        5    en
# 31078  5709E5822F9300CFFD98649E39D7CBFB  14903233        4    en
#
#                                                     text
# 0      Had a delightful time with Lucy at her farm, s...
# 1      We stayed at Kuminda Farm for just one night (...
# 2      We spent a night at Kuminda Farm on our way fr...
# 3      Where would I stop off on my way to Maun or Ka...
# 4      This place is gorgeous and Lucy is such an ama...
# ...                                                  ...
# 31074  When you hear the word Falls ,you imagine wate...
# 31075  A lovely resort some 50kms from Solwezi.  Ther...
# 31076  We had to drive about 45minutes from Solwezi t...
# 31077  An unexpected spot at the end of a sandy road....
# 31078  This is along Solwezi-mwinulunga road, near to...
#
# [31079 rows x 24 columns]

# %%
# print(df.head(10))
info_attraction = info.loc[info['type'] == 'ATTRACTION']
info_attraction
# Out:
#              id        type                       subcategories  \
# 0       7945044  ATTRACTION                  Sights & Landmarks
# 1       1743605  ATTRACTION     Casinos & Gambling, Fun & Games
# 17       311243  ATTRACTION  Sights & Landmarks, Nature & Parks
# 22      2189822  ATTRACTION                      Nature & Parks
# 28     12948270  ATTRACTION                      Nature & Parks
# ...         ...         ...                                 ...
# 13988    479685  ATTRACTION                      Nature & Parks
# 13989   4310058  ATTRACTION                      Nature & Parks
# 14008   1837467  ATTRACTION                      Nature & Parks
# 14015   1985388  ATTRACTION                      Nature & Parks
# 14048  14903233  ATTRACTION                      Nature & Parks
#
#                                       name  \
# 0                             Kuminda Farm
# 1                             Gaborone Sun
# 17                           Tsodilo Hills
# 22             CARACAL Biodiversity Center
# 28                    Chobe Crocodile Farm
# ...                                    ...
# 13988          Mosi-oa-Tunya National Park
# 13989  Parays Game Farm Wildlife Sanctuary
# 14008                  The Night Encounter
# 14015        Chimfunshi Wildlife Orphanage
# 14048                        Mutanda Falls
#
#                                              description  rating  latitude  \
# 0      It's a small farm and we are into Argo tourism...     5.0    -20.98
# 1      Botswana is where the white-hot Kalahari Deser...     4.0    -24.65
# 17     An important rock art site in the western Kala...     4.0    -18.77
# 22     The CARACAL World of Wildlife offers an unique...     4.5    -17.81
# 28     Crocodile Farm, we raise Nile Crocodiles, we o...     5.0    -17.80
# ...                                                  ...     ...       ...
# 13988  This protected wildlife reserve is small at 66...     4.5    -17.93
# 13989  Interested in seeing/interacting with white li...     4.5    -11.75
# 14008  With the awe inspiring spectacle of a star-lad...     5.0    -17.85
# 14015  Chimfunshi Wildlife Orphanage Trust is one of ...     4.5    -12.53
# 14048  It is samall water fall, on Mutanda River, Loc...     4.0    -12.39
#
#        longitude  numberOfReviews      amenities  LowerPrice  UpperPrice  \
# 0          27.25               22  bathroom only       141.0       281.0
# 1          25.93              124  bathroom only       141.0       281.0
# 17         21.75               85  bathroom only       141.0       281.0
# 22         25.15               98  bathroom only       141.0       281.0
# 28         25.23                5  bathroom only       141.0       281.0
# ...          ...              ...            ...         ...         ...
# 13988      25.86              356  bathroom only       141.0       281.0
# 13989      28.72                6  bathroom only       141.0       281.0
# 14008      25.85                3  bathroom only       141.0       281.0
# 14015      27.86               48  bathroom only       141.0       281.0
# 14048      26.24                7  bathroom only       141.0       281.0
#
#        Rank  Total     Location   RankingType   country         city  \
# 0       1.0    3.0  Francistown  things to do  Botswana  Francistown
# 1       4.0   25.0     Gaborone  things to do  Botswana     Gaborone
# 17      1.0    1.0      Shakawe  things to do  Botswana      Shakawe
# 22      1.0    4.0       Kasane  things to do  Botswana       Kasane
# 28      3.0    4.0       Kasane  things to do  Botswana       Kasane
# ...     ...    ...          ...           ...       ...          ...
# 13988   3.0   19.0  Livingstone  things to do    Zambia  Livingstone
# 13989  14.0   33.0       Lusaka  things to do    Zambia       Lusaka
# 14008  16.0   19.0  Livingstone  things to do    Zambia  Livingstone
# 14015   1.0    2.0     Chingola  things to do    Zambia     Chingola
# 14048   1.0    2.0      Solwezi  things to do    Zambia      Solwezi
#
#        regional_rating
# 0             3.000000
# 1             6.250000
# 17            1.000000
# 22            4.000000
# 28            1.333333
# ...                ...
# 13988         6.333333
# 13989         2.357143
# 14008         1.187500
# 14015         2.000000
# 14048         2.000000
#
# [3887 rows x 19 columns]

# %% [markdown]
# #### 2. Preprocessing

# %%
# Convert object columns to categorical

info['type'] = info['type'].astype('category')
info['amenities'] = info['amenities'].astype('category')
info['subcategories'] = info['subcategories'].astype('category')

processor = DataProcessor(info)
clean_info = processor.clean_df

# %%
clean_info
# Out:
#              id        type                    subcategories  \
# 0       7945044  ATTRACTION               Sights & Landmarks
# 1       1743605  ATTRACTION  Casinos & Gambling, Fun & Games
# 2       4162082       HOTEL                Specialty Lodging
# 3       1068835       HOTEL                Bed and Breakfast
# 4      13477853       HOTEL                Specialty Lodging
# ...         ...         ...                              ...
# 14245   6542212       HOTEL                Bed and Breakfast
# 14246   2666970       HOTEL                Bed and Breakfast
# 14247   8118425       HOTEL                Bed and Breakfast
# 14248   1999874       HOTEL                Specialty Lodging
# 14249   1467712       HOTEL                            Hotel
#
#                           name  \
# 0                 Kuminda Farm
# 1                 Gaborone Sun
# 2      Pelican Lodge & Camping
# 3                 Serowe Hotel
# 4               Leopard Plains
# ...                        ...
# 14245  Lima Garden Guest House
# 14246         Manda Hill Lodge
# 14247  BestBed Executive Lodge
# 14248       Four Pillars Lodge
# 14249         The Lusaka Hotel
#
#                                              description  rating  latitude  \
# 0      It's a small farm and we are into Argo tourism...     5.0    -20.98
# 1      Botswana is where the white-hot Kalahari Deser...     4.0    -24.65
# 2      The lodge is situated in Nata, Botswana. Clien...     3.0    -20.22
# 3      Set in beautiful gardens, the Serowe Hotel is ...     3.5    -22.41
# 4      Experience in the middle of the bushveld a lux...     4.5    -20.18
# ...                                                  ...     ...       ...
# 14245  See why so many travelers make Lima Garden Gue...     2.5    -15.38
# 14246  Born in South Africa and taken to the world, N...     1.5    -15.39
# 14247  See why so many travelers make BestBed Executi...     4.0    -12.97
# 14248  Four Pillars Lodge is one of the leading provi...     3.0    -15.41
# 14249  The Lusaka Hotel is the oldest hotel in Lusaka...     2.5    -15.42
#
#        longitude  numberOfReviews  \
# 0          27.25               22
# 1          25.93              124
# 2          26.23              189
# 3          26.72               79
# 4          24.17               56
# ...          ...              ...
# 14245      28.30                4
# 14246      28.31                6
# 14247      28.62                1
# 14248      28.33               14
# 14249      28.28               41
#
#                                                amenities    LowerPrice  \
# 0                                          bathroom only    141.000000
# 1                                          bathroom only    141.000000
# 2      ['Pool', 'Internet', 'Free Internet', 'Free pa...  11533.000000
# 3      ['Pool', 'Internet', 'Free parking', 'Restaura...   6751.000000
# 4      ['Pool', 'Restaurant', 'Wifi', 'Breakfast incl...  32911.000000
# ...                                                  ...           ...
# 14245  ['Pool', 'Room service', 'Restaurant', 'Air co...  13777.392428
# 14246  ['Internet', 'Kids Activities', 'Suites', 'Roo...   6329.000000
# 14247  ['Kids Activities', 'Room service', 'Free park...  13777.392428
# 14248  ['Pool', 'Internet', 'Suites', 'Free Internet'...  10689.000000
# 14249  ['Suites', 'Breakfast included', 'Pool', 'Inte...   9283.000000
#
#          UpperPrice  Rank  Total     Location        RankingType   country  \
# 0        281.000000   1.0    3.0  Francistown       things to do  Botswana
# 1        281.000000   4.0   25.0     Gaborone       things to do  Botswana
# 2      13361.000000   4.0    9.0         Nata  Specialty lodging  Botswana
# 3       6892.000000   1.0    7.0       Serowe  Specialty lodging  Botswana
# 4      41632.000000  10.0   81.0         Maun  Specialty lodging  Botswana
# ...             ...   ...    ...          ...                ...       ...
# 14245  23045.636246  46.0  130.0       Lusaka  Specialty lodging    Zambia
# 14246  12658.000000  48.0  130.0       Lusaka  Specialty lodging    Zambia
# 14247  23045.636246   9.0   21.0        Ndola  Specialty lodging    Zambia
# 14248  10830.000000  63.0  156.0       Lusaka  Specialty lodging    Zambia
# 14249  18284.000000  38.0   66.0       Lusaka             hotels    Zambia
#
#               city  regional_rating
# 0      Francistown         3.000000
# 1         Gaborone         6.250000
# 2             Nata         2.250000
# 3           Serowe         7.000000
# 4             Maun         8.100000
# ...            ...              ...
# 14245       Lusaka         2.826087
# 14246       Lusaka         2.708333
# 14247        Ndola         2.333333
# 14248       Lusaka         2.476190
# 14249       Lusaka         1.736842
#
# [14250 rows x 19 columns]

# %% [markdown]
# #### 3. Modelling
# Train SVD & KNN model based on known user's(userId) rating(rating_y) for some item(placeid), then select the top few rated items as recommendations by predicting ratings for all unrated items.

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(merged_reviews_info[['userId', 'placeid', 'rating_y']], reader)

trainset, testset = train_test_split(data, test_size=0.2)

print('---Training SVD---')
svd = SVD()
svd.fit(trainset)
svd_predictions = svd.test(testset)
svd_rmse = accuracy.rmse(svd_predictions)

print('---Training KNNWithMeans---')
knn = KNNWithMeans()
knn.fit(trainset)
knn_predictions = knn.test(testset)
knn_rmse = accuracy.rmse(knn_predictions)

print('---Validate SVD---')
svd_cv = cross_validate(SVD(), data, measures=['RMSE'], cv=5, verbose=True)
print('---Validate KNNWithMeans---')
knn_cv = cross_validate(KNNWithMeans(), data, measures=['RMSE'], cv=5, verbose=True)

# Suppose we need to generate recommendations for a certain user (user_id)user_id = '2A5836BDB7EDEEB43BF1F6AE6A9C28F7'
user_ratings = merged_reviews_info[merged_reviews_info['userId'] == user_id]

all_items = merged_reviews_info['placeid'].unique()
rated_items = user_ratings['placeid'].unique()
unrated_items = [item for item in all_items if item not in rated_items]

predictions = [(item, svd.predict(user_id, item).est) for item in unrated_items]
predictions.sort(key=lambda x: x[1], reverse=True)

top_n = 10
recommendations = predictions[:top_n]

print(f"SVD: Top {top_n} recommendations for user {user_id}: {recommendations}")


knn_predictions = [(item, knn.predict(user_id, item).est) for item in unrated_items]
knn_predictions.sort(key=lambda x: x[1], reverse=True)

knn_recommendations = knn_predictions[:top_n]

print(f"KNNWithMeans: Top {top_n} recommendations for user {user_id}: {knn_recommendations}")

svd_predictions = svd.test(testset)
knn_predictions = knn.test(testset)

svd_rmse = accuracy.rmse(svd_predictions)
knn_rmse = accuracy.rmse(knn_predictions)

print(f'SVD RMSE: {svd_rmse}')
print(f'KNNWithMeans RMSE: {knn_rmse}')

# Get similar users by finding nearest neighbors for group recommendation
user_inner_id = knn.trainset.to_inner_uid(user_id)  
neighbors = knn.get_neighbors(user_inner_id, k=3)  # Get the internal IDs of the K most similar neighbors

neighbors = [knn.trainset.to_raw_uid(inner_id) for inner_id in neighbors]

print(f"The 3 nearest neighbors of user {user_id} are: {neighbors}")

for neighbor in neighbors:
    neighbor_ratings = merged_reviews_info[merged_reviews_info['userId'] == neighbor]
    print(f"Ratings by neighbor {neighbor}:")
    print(neighbor_ratings)
# Out:
# ---Training SVD---
# RMSE: 0.6543
# ---Training KNNWithMeans---
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.7257
# ---Validate SVD---
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.6483  0.6412  0.6561  0.6448  0.6453  0.6471  0.0050
# Fit time          0.22    0.21    0.21    0.21    0.22    0.21    0.00
# Test time         0.02    0.02    0.02    0.02    0.02    0.02    0.00
# ---Validate KNNWithMeans---
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.7183  0.7117  0.7252  0.7269  0.7318  0.7228  0.0070
# Fit time          7.43    7.42    7.09    7.63    7.85    7.48    0.25
# Test time         0.09    0.10    0.08    0.10    0.08    0.09    0.01
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 24
#      21 knn_cv = cross_validate(KNNWithMeans(), data, measures=['RMSE'], cv=5, verbose=True)
#      23 # Suppose we need to generate recommendations for a certain user (user_id)user_id = '2A5836BDB7EDEEB43BF1F6AE6A9C28F7'
# ---> 24 user_ratings = merged_reviews_info[merged_reviews_info['userId'] == user_id]
#      26 all_items = merged_reviews_info['placeid'].unique()
#      27 rated_items = user_ratings['placeid'].unique()
#
# NameError: name 'user_id' is not defined

# %%
# import pandas as pd
# from surprise import Dataset, Reader, KNNWithMeans, accuracy
# from surprise.model_selection import train_test_split, cross_validate
# # 将DataFrame转换为Surprise数据集格式

# reader = Reader(rating_scale=(1, 5))
# data = Dataset.load_from_df(merged_reviews_info[['userId', 'placeid', 'rating_y']], reader)

# trainset, testset = train_test_split(data, test_size=0.2)
#
# print('---Training KNNWithMeans---')
# sim_options = {
#     'name': 'cosine',
#     'user_based': True
# }
# knn = KNNWithMeans(k=3, sim_options=sim_options)  # 设定K值为3
# knn.fit(trainset)
# knn_predictions = knn.test(testset)
# knn_rmse = accuracy.rmse(knn_predictions)

# user_ratings = merged_reviews_info[merged_reviews_info['userId'] == user_id]
# all_items = merged_reviews_info['placeid'].unique()
# rated_items = user_ratings['placeid'].unique()
# unrated_items = [item for item in all_items if item not in rated_items]

# knn_predictions = [(item, knn.predict(user_id, item).est) for item in unrated_items]
# knn_predictions.sort(key=lambda x: x[1], reverse=True)

# print("All predictions:")
# for item, score in knn_predictions:
#     print(f"Item: {item}, Predicted Score: {score}")

# top_n = 10
# knn_recommendations = knn_predictions[:top_n]

# print(f"Top {top_n} recommendations for user {user_id} using KNNWithMeans: {knn_recommendations}")

# knn_predictions = knn.test(testset)

# knn_rmse = accuracy.rmse(knn_predictions)

# print(f'KNNWithMeans RMSE: {knn_rmse}')

# user_id = 'A38CEED23744265FCA6202C3869DFE93'
# user_inner_id = knn.trainset.to_inner_uid(user_id) 
# neighbors = knn.get_neighbors(user_inner_id, k=3) 

# neighbors = [knn.trainset.to_raw_uid(inner_id) for inner_id in neighbors]
# print(f"The 3 nearest neighbors of user {user_id} are: {neighbors}")

# for neighbor in neighbors:
#     neighbor_ratings = merged_reviews_info[merged_reviews_info['userId'] == neighbor]
#     print(f"Ratings by neighbor {neighbor}:")
#     print(neighbor_ratings)
# Out:
# ---Training KNNWithMeans---
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.7376
# All predictions:
# Item: 24091522, Predicted Score: 4.691951896392229
# Item: 23854639, Predicted Score: 4.691951896392229
# Item: 20174710, Predicted Score: 4.691951896392229
# Item: 15561037, Predicted Score: 4.691951896392229
# Item: 19204589, Predicted Score: 4.691951896392229
# Item: 23591002, Predicted Score: 4.691951896392229
# Item: 14251907, Predicted Score: 4.691951896392229
# Item: 20195008, Predicted Score: 4.691951896392229
# Item: 7945044, Predicted Score: 4.0
# Item: 1743605, Predicted Score: 4.0
# Item: 311243, Predicted Score: 4.0
# Item: 2189822, Predicted Score: 4.0
# Item: 12948270, Predicted Score: 4.0
# Item: 479156, Predicted Score: 4.0
# Item: 5975965, Predicted Score: 4.0
# Item: 7110471, Predicted Score: 4.0
# Item: 8476619, Predicted Score: 4.0
# Item: 8801391, Predicted Score: 4.0
# Item: 9564618, Predicted Score: 4.0
# Item: 20171007, Predicted Score: 4.0
# Item: 8643447, Predicted Score: 4.0
# Item: 13970670, Predicted Score: 4.0
# Item: 13293550, Predicted Score: 4.0
# Item: 25079580, Predicted Score: 4.0
# Item: 20323811, Predicted Score: 4.0
# Item: 7699267, Predicted Score: 4.0
# Item: 8806327, Predicted Score: 4.0
# Item: 8743109, Predicted Score: 4.0
# Item: 4467230, Predicted Score: 4.0
# Item: 8322054, Predicted Score: 4.0
# Item: 10689442, Predicted Score: 4.0
# Item: 13859729, Predicted Score: 4.0
# Item: 15872869, Predicted Score: 4.0
# Item: 17540804, Predicted Score: 4.0
# Item: 5608092, Predicted Score: 4.0
# Item: 8779499, Predicted Score: 4.0
# Item: 11720886, Predicted Score: 4.0
# Item: 13340495, Predicted Score: 4.0
# Item: 5570680, Predicted Score: 4.0
# Item: 12516280, Predicted Score: 4.0
# Item: 13238821, Predicted Score: 4.0
# Item: 7691935, Predicted Score: 4.0
# Item: 10333033, Predicted Score: 4.0
# Item: 23728158, Predicted Score: 4.0
# Item: 12870218, Predicted Score: 4.0
# Item: 25149043, Predicted Score: 4.0
# Item: 13426146, Predicted Score: 4.0
# Item: 25351014, Predicted Score: 4.0
# Item: 13565202, Predicted Score: 4.0
# Item: 17426202, Predicted Score: 4.0
# Item: 506754, Predicted Score: 4.0
# Item: 23877841, Predicted Score: 4.0
# Item: 13951570, Predicted Score: 4.0
# Item: 25131411, Predicted Score: 4.0
# Item: 10234888, Predicted Score: 4.0
# Item: 14132910, Predicted Score: 4.0
# Item: 4787695, Predicted Score: 4.0
# Item: 12282604, Predicted Score: 4.0
# Item: 7645079, Predicted Score: 4.0
# Item: 9862268, Predicted Score: 4.0
# Item: 12288823, Predicted Score: 4.0
# Item: 2433257, Predicted Score: 4.0
# Item: 2577821, Predicted Score: 4.0
# Item: 2252040, Predicted Score: 4.0
# Item: 1181356, Predicted Score: 4.0
# Item: 2658186, Predicted Score: 4.0
# Item: 2324294, Predicted Score: 4.0
# Item: 1788507, Predicted Score: 4.0
# Item: 3605685, Predicted Score: 4.0
# Item: 13339312, Predicted Score: 4.0
# Item: 501759, Predicted Score: 4.0
# Item: 13953569, Predicted Score: 4.0
# Item: 478676, Predicted Score: 4.0
# Item: 10347363, Predicted Score: 4.0
# Item: 480657, Predicted Score: 4.0
# Item: 4325305, Predicted Score: 4.0
# Item: 782640, Predicted Score: 4.0
# Item: 12667077, Predicted Score: 4.0
# Item: 4310058, Predicted Score: 4.0
# Item: 1837467, Predicted Score: 4.0
# Top 10 recommendations for user A38CEED23744265FCA6202C3869DFE93 using KNNWithMeans: [(24091522, 4.691951896392229), (23854639, 4.691951896392229), (20174710, 4.691951896392229), (15561037, 4.691951896392229), (19204589, 4.691951896392229), (23591002, 4.691951896392229), (14251907, 4.691951896392229), (20195008, 4.691951896392229), (7945044, 4.0), (1743605, 4.0)]
# RMSE: 0.7376
# KNNWithMeans RMSE: 0.7375871561084639
# The 3 nearest neighbors of user A38CEED23744265FCA6202C3869DFE93 are: ['49785D7966622F36D18B8238F43311D7', 'BE4E3055F78F7BCC56D535EAD892F409', '6A7B16773CDC07A373946FDDE5CAB3CE']
# Ratings by neighbor 49785D7966622F36D18B8238F43311D7:
#             id        type   subcategories                           name  \
# 31041  1985388  ATTRACTION  Nature & Parks  Chimfunshi Wildlife Orphanage
#
#                                              description  rating_x  latitude  \
# 31041  Chimfunshi Wildlife Orphanage Trust is one of ...       4.5    -12.53
#
#        longitude  numberOfReviews      amenities  ...  Location   RankingType  \
# 31041      27.86               48  bathroom only  ...  Chingola  things to do
#
#        country      city regional_rating                            userId  \
# 31041   Zambia  Chingola             2.0  49785D7966622F36D18B8238F43311D7
#
#        placeid rating_y  lang  \
# 31041  1985388        5    en
#
#                                                     text
# 31041  Worth a visit to experience the unique creatur...
#
# [1 rows x 24 columns]
# Ratings by neighbor BE4E3055F78F7BCC56D535EAD892F409:
#              id        type   subcategories           name  \
# 31077  14903233  ATTRACTION  Nature & Parks  Mutanda Falls
#
#                                              description  rating_x  latitude  \
# 31077  It is samall water fall, on Mutanda River, Loc...       4.0    -12.39
#
#        longitude  numberOfReviews      amenities  ...  Location   RankingType  \
# 31077      26.24                7  bathroom only  ...   Solwezi  things to do
#
#        country     city regional_rating                            userId  \
# 31077   Zambia  Solwezi             2.0  BE4E3055F78F7BCC56D535EAD892F409
#
#         placeid rating_y  lang  \
# 31077  14903233        5    en
#
#                                                     text
# 31077  An unexpected spot at the end of a sandy road....
#
# [1 rows x 24 columns]
# Ratings by neighbor 6A7B16773CDC07A373946FDDE5CAB3CE:
#             id        type   subcategories                           name  \
# 31044  1985388  ATTRACTION  Nature & Parks  Chimfunshi Wildlife Orphanage
#
#                                              description  rating_x  latitude  \
# 31044  Chimfunshi Wildlife Orphanage Trust is one of ...       4.5    -12.53
#
#        longitude  numberOfReviews      amenities  ...  Location   RankingType  \
# 31044      27.86               48  bathroom only  ...  Chingola  things to do
#
#        country      city regional_rating                            userId  \
# 31044   Zambia  Chingola             2.0  6A7B16773CDC07A373946FDDE5CAB3CE
#
#        placeid rating_y  lang  \
# 31044  1985388        3    en
#
#                                                     text
# 31044  All things being equal not worth the trip on t...
#
# [1 rows x 24 columns]

# %% [markdown]
# ### Content-based Filtering:
#
# It bases its recommendations on content description information (attractions/hotels/restaurant/locations) to visit, etc.).
#
# The advantage of content-based recommendation is that it can provide accurate recommendations based on the user's personalized needs and does not require additional information such as user ratings. However, this algorithm requires high accuracy and completeness of (attractions/hotels/restaurant/locations) descriptions, and may not be effective for new users or cold (attractions/hotels/restaurant/locations) recommendations.

# %%
info = pd.read_csv('../data/test_travel_data.csv')

vectorization_columns = info[['name', 'subcategories', 'amenities']]

df = info[info["type"]== "ATTRACTION"]

df['combined_text'] = df['subcategories'] + " " + df['description'] + " " + df['amenities']

# Apply TF-IDF vectorization
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
# tfidfv_matrix2=tfidfv2.fit_transform(info['description'])
tfidf_matrix = tfidf_vectorizer.fit_transform(df['combined_text'])

# Compute cosine similarity matrix
cosine_sim_matrix = cosine_similarity(tfidf_matrix)

# Find the attraction which is similar with "Kuminda Farm"
similar_attractions = get_similar_attractions('Kuminda Farm', df, cosine_sim_matrix)
print("Recommended Attractions:" )
print(similar_attractions)
# Out:
# /var/folders/md/00znqx716_b042ykzg2k80g80000gn/T/ipykernel_67125/1730613307.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['combined_text'] = df['subcategories'] + " " + df['description'] + " " + df['amenities']
# Recommended Attractions:
#            id        type       subcategories                    name  \
# 958   2706237  ATTRACTION  Sights & Landmarks  The Heavenly Cathedral
# 427  13293550  ATTRACTION  Sights & Landmarks               Positivos
#
#                                            description  rating  latitude  \
# 958                                                        5.0     27.89
# 427  Cultural place in Mindelo with Live Music, Cin...     4.0     16.89
#
#      longitude  numberOfReviews      amenities  LowerPrice  UpperPrice  Rank  \
# 958      34.30             1087  bathroom only       141.0       281.0   1.0
# 427     -24.99                4  bathroom only       141.0       281.0  12.0
#
#      Total         Location   RankingType     country             city  \
# 958   50.0  Sharm El Sheikh  things to do       Egypt  Sharm El Sheikh
# 427   16.0          Mindelo  things to do  Cape Verde          Mindelo
#
#      regional_rating                                      combined_text
# 958        50.000000                 Sights & Landmarks   bathroom only
# 427         1.333333  Sights & Landmarks Cultural place in Mindelo w...
